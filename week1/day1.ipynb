# %%
# imports


import os
from openai import OpenAI
from dotenv import load_dotenv


# Load variables from .env
load_dotenv()
# Read the API key
api_key = os.getenv("OPENAI_API_KEY")
print(api_key)

client = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key=api_key     # Any non-empty string works
)

response = client.chat.completions.create(
    model="gemma4:latest",
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant."
        },
        {
            "role": "user",
            "content": "Explain what Context Engineering is."
        }
    ]
)

print(response.choices[0].message.content)

# If you get an error running this cell, then please head over to the troubleshooting notebook!
# Out:
# Context Engineering is a sophisticated and rapidly growing discipline that involves the **systematic design, management, and application of surrounding information** to ensure that an Artificial Intelligence model—most commonly Large Language Models (LLMs)—operates reliably, accurately, and with highly relevant focus in specific use cases.
#
# In simplest terms: **It is the process of providing the AI with all the necessary background knowledge, rules, roles, and guardrails so it can perform its task correctly without making irrelevant assumptions or "hallucinating."**
#
# ***
#
# ## 💡 Why Is Context Engineering Necessary? (The Problem It Solves)
#
# Modern LLMs are powerful generalization engines. They are trained on massive datasets spanning the entire internet, giving them vast knowledge but little structured focus. If you ask a general-purpose model to answer a question about your internal company policy, it will fail because it doesn't know *your* policies.
#
# Context Engineering solves this lack of specificity by preventing the AI from relying solely on its massive, general training data and instead forcing it to operate only within a controlled, defined "context."
#
# **Think of it this way:**
# *   **A powerful LLM without context** is like a brilliant but disorganized scholar who knows everything but has no filing cabinet.
# *   **Context Engineering** is the process of giving that scholar a specific rulebook (the constraints), a locked filing cabinet full of relevant, verified documents (the knowledge base), and telling them exactly which folder to open first (the prompt/workflow).
#
# ***
#
# ## 🛠️ The Core Components: How Context Is Engineered
#
# Context Engineers work by implementing structures across three main layers: **Knowledge, Logic,** and **Structure.**
#
# ### 1. Knowledge Augmentation (The Data)
# This is the most visible component. Instead of relying on the LLM's pre-trained memory, you feed it verified, specific data.
#
# *   **Technique:** **Retrieval-Augmented Generation (RAG).** This is the single most common practical application. The system first *retrieves* relevant documents (e.g., PDFs, database records) related to the user's query and then passes those documents into the prompt context window for the LLM to read before generating an answer.
# *   **Effect:** Eliminates hallucinations because the model is forced to cite or base its answers only on the provided source material.
#
# ### 2. System Logic (The Rules)
# This layer defines *how* and *when* the AI should think, respond, and behave.
#
# *   **Persona/Role Assignment:** Engineering a specific role into the prompt allows the model to adopt a narrow viewpoint ("You are a senior financial analyst...") which limits its response scope and tone.
# *   **Guardrails and Constraints:** Implementing explicit rules that dictate what the model *cannot* say, or how it must format an answer (e.g., "Do not write more than 3 bullet points," "Always cite the section in the provided text").
#
# ### 3. Structural Input (The Prompt)
# This refines the initial instruction set and workflow, ensuring clarity from start to finish.
#
# *   **Few-Shot Learning:** Giving the model several examples of desired input/output pairs within the prompt itself. It doesn't teach it code or facts; it teaches it *format*.
# *   **Chain-of-Thought (CoT):** Asking the model not just for an answer, but to "think step by step." This engineered process forces internal reasoning and often leads to better logical outcomes than asking for a direct answer.
#
# ***
#
# ## 🥊 Context Engineering vs. Prompt Engineering
#
# These terms are related but not interchangeable. Understanding their difference is key:
#
# | Feature | Prompt Engineering (Focus: Syntax) | Context Engineering (Focus: System Design) |
# | :--- | :--- | :--- |
# | **Goal** | Optimizing the text input to get a better immediate output. | Designing the entire system workflow and surrounding knowledge base for repeatable, enterprise-grade performance. |
# | **Scope** | The specific wording of the prompt itself (e.g., changing "Tell me about X" to "Analyze X based on criteria Y"). | Includes data sources, pre/post-processing steps, memory management, guardrails, and retrieval mechanisms in addition to the prompt. |
# | **Example** | Telling a model: *"Act as a lawyer..."* | Building an entire system that *first queries a legal database using vector embeddings*, *then passes the results into the LLM*, and finally has the model *format its answer according to specific legal citation rules.* |
#
# ***
#
# ## 🌟 Summary of Value
#
# Context Engineering transforms a general-purpose, potentially erratic AI tool into a **highly specialized, reliable application**.
#
# It moves AI development away from simple "chatbots" towards robust, mission-critical systems that:
# 1.  **Are Trustworthy:** Because they are tied to internal, verifiable documents (RAG).
# 2.  **Are Relevant:** Because their focus is artificially constrained by defined roles and rules.
# 3.  **Are Actionable:** Because the output is forced into a useful format (JSON, markdown tables, etc.).
